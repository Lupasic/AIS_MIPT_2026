# %% [markdown]
# # Kaggle

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mrisdal/zurich-urban-micro-aerial-vehicle",output_dir="../datasets/zurich")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 280M/280M [02:11<00:00, 2.22MB/s]
# Extracting files...
# Path to dataset files: ../datasets/zurich

# %% [markdown]
# # Hugging Face
# ## Huggingface_hub

# %%
from pathlib import Path
from huggingface_hub import snapshot_download

out_dir = Path("../datasets/ITLP-Campus-Outdoor")
out_dir.mkdir(parents=True, exist_ok=True)

snapshot_download(repo_id="OPR-Project/ITLP-Campus-Outdoor", repo_type="dataset",allow_patterns=["02_2023-03-15/*"], local_dir=out_dir)
# Out:
# Fetching ... files: 3141it [07:53,  6.63it/s]
# '/home/lupasic/Programs/clearml_tests/datasets/ITLP-Campus-Outdoor'

# %% [markdown]
# ## datasets

# %%
from datasets import load_dataset

ds = load_dataset("gafoart/gafoart")
# Out:
# Generating train split: 484 examples [00:00, 1381.46 examples/s]
# ---------------------------------------------------------------------------
# NonMatchingSplitsSizesError               Traceback (most recent call last)
# Cell In[6], line 3
#       1 from datasets import load_dataset
# ----> 3 ds = load_dataset("gafoart/gafoart")
#
# File ~/Programs/clearml_tests/.pixi/envs/default/lib/python3.10/site-packages/datasets/load.py:1505, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1502     return builder_instance.as_streaming_dataset(split=split)
#    1504 # Download and prepare data
# -> 1505 builder_instance.download_and_prepare(
#    1506     download_config=download_config,
#    1507     download_mode=download_mode,
#    1508     verification_mode=verification_mode,
# ...
